# %%
from tools import read_data
import pandas as pd 
import glob 
import os 
import numpy as np
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import scipy.io as sio

# %%
MyFiles = [] 
MyFiles = glob.glob(r"C:\Users\fmora103\University of Ottawa\BeiqueLab - Documents\CURRENT LAB MEMBERS\Nastaran Kosarmadar\Electrophysiology data\Data\Thomas recording\M4\feb 3\*.rhd")

# %%
'base' in MyFiles[16]
# Out:
# True

# %%
amp8  = np.array([])
amp10 = np.array([])
amp20 = np.array([])
amp22 = np.array([])
t     = np.array([])  


for i in MyFiles:
    if 'base' in i:
        header, data = read_data(i)
        amp8  = np.append(amp8, data['amplifier_data'][8,:])
        amp10 = np.append(amp10, data['amplifier_data'][10,:])
        amp20 = np.append(amp20, data['amplifier_data'][20,:])
        amp22 = np.append(amp22, data['amplifier_data'][22,:])
        t     = np.append(t, data['t_amplifier'])
# Out:
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# n signal groups 7
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 0 board digital input channels.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 60.012 seconds of data.  Amplifiers were sampled at 20.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 2.7 seconds
#
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# n signal groups 7
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 0 board digital input channels.
# Found 0 board digital output channels.
# ...

# %%
tshape = (t.shape[0])
duration_in_sec = tshape/20000
duration_in_min = duration_in_sec/60
print (duration_in_sec)
print (duration_in_min)
# Out:
# 11441.34
# 190.689

# %%
tetrode = np.vstack((amp22, amp8, amp10, amp20)).T
tetrode.shape
# Out:
# (228826800, 4)

# %%
raw_filename = r'C:\Users\fmora103\Desktop\Nastaran Data\M3Feb3.raw'
with open(raw_filename, mode='wb') as f:
    f.write(tetrode.astype('int16').tobytes())

# %%
import scipy.io as sio
mdic = {"a":tetrode, "label":'op'}
sio.savemat('/Volumes/Project/Nastaran Project/New data/Cortex.mat',mdic)
